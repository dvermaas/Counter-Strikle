# %% [markdown]
# # Counter Strikle Webscraper

# %% [markdown]
# > The following code scrapes liquidpedia (https://liquipedia.net/counterstrike/Main_Page), in order to make counter strikle (https://blast.tv/counter-strikle) puzzle-solving easier.

# %% [markdown]
# # Libs

# %%
import os
import csv
import time
from time import sleep
from bs4 import BeautifulSoup
from datetime import datetime

import numpy as np
import pandas as pd
#pd.set_option("display.max_rows", None)
from tqdm.notebook import tqdm
import requests
from urllib.request import quote

# %%
headers = {"User-Agent": "Counter-Strikle-Bot","Accept-Encoding": "gzip"}
base_url = "https://liquipedia.net/counterstrike/api.php?"
REGIONS = {"Europe" : ["Europe", "CIS"], "Americas" : ["Americas"],
           "Asia-Pacific" : ["Oceania", "Eastern_%26_Southern_Asia"]}
CSV_FILE = "players2.csv"
COLUMNS = ["NAME", "REAL NAME", "REGION", "NATIONALITY", "TEAM", "AGE", "WEAPON", 
           "MAJOR APPEARANCES", "EARNINGS", "LAST UPDATED"]

def fetch_page(page):
    url = base_url +"action=parse&format=json&page=" + page
    response = requests.get(url, headers)
    page_html = response.json()['parse']['text']['*']
    soup = BeautifulSoup(page_html,features="lxml")
    time.sleep(30)
    return soup

# %%
def fetch_majors():
    soup = fetch_page("Majors")
    event_elements = soup.find_all("div", {"class": "divRow tournament-card-premier"})
    return [event.find("b").find("a")["href"] for event in event_elements]

#fetch_majors()

# %%
def fetch_ids(region):
    page = fetch_page("Portal:Players/" + region)
    elements = [item.find_all("a")[1] for item in page.find_all("td")]
    name_dict = [element["title"].replace(" ","_") for element in elements]
    return name_dict

#fetch_ids("Europe")
# Out:
# ['Stikle-',
#  'ChrissK',
#  'Dukiiii',
#  'Kakafu',
#  'NinoZjE',
#  'Orbit',
#  'ReacTioNNN',
#  'S3NSEY',
#  'SesL',
#  'TWEEZYCS',
#  'XTreMe',
#  'AntO_oNNN',
#  'Claeys',
#  'FARIS',
#  'Infernal',
#  'Keoz',
#  'KllyVe',
#  'Kzealos',
#  'MetaL',
#  'Monu',
#  'Nexius',
#  'RitchiEE',
#  'Simix',
#  'Stev0se',
#  'To1nou',
#  'YNc',
#  'HuNter-',
#  'NiKo',
#  'Sarenii',
#  'Blocker',
#  'Bubble',
#  'CeRq',
#  'Dennyslaw',
#  'Doublemagic',
#  'Dream3r',
#  'Duplicate',
#  'H4rn',
#  'KalubeR',
#  'Mar',
#  'Niki1',
#  'Numb',
#  'Oxygen',
#  'Patrick_(Bulgarian_player)',
#  'PNshr',
#  'Poizon',
#  'POP0V',
#  'Rafftu',
#  'Rainwaker',
#  'REDSTAR',
#  'Rock1nG',
#  'ShaiK',
#  'SHiPZ',
#  'SPELLAN',
#  'SpyleadeR',
#  'ToH1o',
#  'V1c7oR',
#  'Zix',
#  'AJTT',
#  'Beastik',
#  'Bfull',
#  'Blogg1s',
#  'CapseN',
#  'Daxen',
#  'Desty',
#  'DEV7L',
#  'Dytor',
#  'EYO',
#  'Forsyy',
#  'Fraged',
#  'Fredi',
#  'HONES',
#  'K1-FiDa',
#  'Kinzo',
#  'Leckr',
#  'Levi',
#  'Manguss',
#  'MoriiSko',
#  'Nbqq',
#  'NEOFRAG',
#  'Oskar',
#  'Pechyn',
#  'SHOCK',
#  'Stinx',
#  'SyncD',
#  'Tomkeejs',
#  'Twist_(Czech_player)',
#  'Valencio',
#  'ZEDKO',
#  'Zur1s',
#  'AcilioN',
#  'AcoR',
#  'Aizy',
#  'Alexsomfan',
#  'Altekz',
#  'Ave',
#  'B0RUP',
#  'Basso',
#  'BERRY',
#  'Birdfromsky',
#  'BlameF',
#  'Blaq',
#  'Brzer',
#  'Buzz',
#  'Cabbi',
#  'CadiaN',
#  'Cajunb',
#  'Casle',
#  'Celebrations',
#  'Celrate',
#  'Console',
#  'Daffu',
#  'Dev1ce',
#  'Dfen',
#  'Doktizh',
#  'DragoNfly',
#  'Dupreeh',
#  'Es3tag',
#  'Farlig',
#  'Fessor',
#  'FeTiSh',
#  'Friis',
#  'Frøslev',
#  'Gade',
#  'Gla1ve',
#  'Haste',
#  'Holzt',
#  'HooXi',
#  'HUNDEN',
#  'IceBerg',
#  'J3nsyy',
#  'Jabbi',
#  'K0nfig',
#  'Karrigan',
#  'KiR',
#  'Kjaerbye',
#  'KolibrieN',
#  'Kraghen',
#  'Kristou',
#  'Kwezz',
#  'Larsen',
#  'LOMME',
#  'Lucky_(Danish_player)',
#  'Lukki',
#  'Magisk',
#  'MaNkz',
#  'Maze',
#  'Mertz',
#  'Minet',
#  'MistR',
#  'MithR',
#  'MSL',
#  'MupzG',
#  'NaToSaphiX',
#  'Netrick',
#  'Nicoodoz',
#  'Niko_(Danish_player)',
#  'Nodios',
#  'NotaN',
#  'PERCY',
#  'PR1mE',
#  'Q-Q',
#  'Queenix',
#  'Raalz',
#  'Refrezh',
#  'Rejin',
#  'Rezex',
#  'RoeJ',
#  'Ruggah',
#  'Rytter',
#  'Ryxxo',
#  'SandeN',
#  'SiNde',
#  'Sjuush',
#  'SmF',
#  'Snappi',
#  'Snedker',
#  'Staehr',
#  'Stavn',
#  'Sycrone',
#  'Tauson',
#  'Tenzki',
#  'TeSeS',
#  'Thamlike',
#  'TMB',
#  'TOBIZ',
#  'Toft',
#  'Torben',
#  'Trace',
#  'Twinx',
#  'Valde',
#  'Vigg0',
#  'Vorborg',
#  'Winspai',
#  'Xyp9x',
#  'Zeq',
#  'Zonic',
#  'Zyphon',
#  'Zypztw',
#  'Dodz',
#  'Eku',
#  'FejtZ',
#  'Gaborik',
#  'HeLIX',
#  'HS',
#  'Jyo',
#  'Nyte',
#  'Ropz',
#  'Shokz',
#  'Sperr',
#  'Supra',
#  'ViztA',
#  'Wahtzz',
#  'Aerial',
#  'Aleksib',
#  'Allu',
#  'APEHEHE',
#  'Arvid',
#  'Aune',
#  'Banjo',
#  'BONA',
#  'Choco',
#  'Doto',
#  'EDi',
#  'Elfern',
#  'Heku',
#  'HENU',
#  'JALLU',
#  'Jelo',
#  'Jemi',
#  'Jimpphat',
#  'JOELZ',
#  'Juho',
#  'KIPSIk',
#  'LYNXi',
#  'Moonsh1n3',
#  'Myltsi',
#  'Oopee',
#  'Osku',
#  'OttoNd',
#  'Peku',
#  'S1rva',
#  'SADDYX',
#  'Samppa',
#  'SAw',
#  'Sergej',
#  'SLowi',
#  'Sm1llee',
#  'Spargo',
#  'STOVVE',
#  'SuNny',
#  'Tomsku',
#  'ToNppa',
#  'Twista',
#  'Uli',
#  'XartE',
#  'XseveN',
#  'ZehN',
#  'Zks',
#  'ZOREE',
#  'Afro',
#  'AM',
#  'AMANEK',
#  'ApEX',
#  'AtLaNtis',
#  'Bisou',
#  'Bodyy',
#  'BouLy',
#  'DEVIL',
#  'Devoduvek',
#  'Djoko',
#  'DrqkoN',
#  'EMYOR',
#  'Ex3rcice',
#  'FantEN',
#  'Flex0r',
#  'Fuks',
#  'Gringo',
#  'HAdji',
#  'JACKZ',
#  'Jarod',
#  'JeyN',
#  'JiNKZ',
#  'Kan4',
#  'KennyS',
#  'Kim',
#  'KioShiMa',
#  'Krav',
#  'KRL',
#  'Kyojin',
#  'Lalità',
#  'Lambert',
#  'LiptoN',
#  'Lucky_(French_player)',
#  'Madc',
#  'MAIDHEN',
#  'Maka',
#  'MaLeK',
#  'Malikof',
#  'Mar1on',
#  'MaT',
#  'MatHEND',
#  'META',
#  'Missa',
#  'Misutaaa',
#  'Monkey_D._Julie',
#  'NBK-',
#  'NiaK',
#  'Ninis',
#  'Nonick',
#  'Ozstrik3r',
#  'Python',
#  'RobiNasTy',
#  'S0ne',
#  'SBT',
#  'Shox',
#  'SIXER',
#  'Smyli',
#  'Victorztw',
#  'VKLL',
#  'WaneG',
#  'WasiNk',
#  'XpG',
#  'XTQZZZ',
#  'ZywOo',
#  'Adinbisplatna',
#  'Am0',
#  'Andyy',
#  'Anhuin',
#  'Aqua',
#  'Ayken',
#  'Bonga',
#  'Boostey',
#  'Cello',
#  'Crisby',
#  'Cyx',
#  'Dav1dK',
#  'DeniMM',
#  'Denis',
#  'DevraNN',
#  'DreaM-',
#  'DuDe',
#  'EcfN',
#  'Enkay_J',
#  'Failzzr',
#  'FaveN',
#  'FreeZe',
#  'Get_(German_player)',
#  'Gimpen',
#  'GlaVed',
#  'Gob_b',
#  'HadeZ',
#  'Hyde',
#  'Hyped',
#  'J0hnny',
#  'J1NZO',
#  'JDC',
#  'Jinjin',
#  'Julie',
#  'K1to',
#  'KiNGDOM',
#  'Kirby',
#  'Knoxville_(German_player)',
#  'Kressy',
#  'Krimbo',
#  'KrowNii',
#  'KRYSTAL',
#  'Kyuubii',
#  'Kzy',
#  'LapeX',
#  'Lefty',
#  'LyGHT',
#  'MaRky',
#  'Mave',
#  'Mirbit',
#  'MvN',
#  'NeviZ',
#  'Oddo',
#  'P4TriCK',
#  'PANIX',
#  'Pdy',
#  'PerX',
#  'PowerYY',
#  'Pr1metapz',
#  'Preet',
#  'Prosus',
#  'PulzG',
#  'R0bs3n',
#  'Rapala',
#  'Red_(German_player)',
#  'S1n',
#  'SchwaByyjee',
#  'ScrunK',
#  'Sha',
#  'Skyye',
#  'Slaxz-',
#  'Spiidi',
#  'StfN',
#  'Swani',
#  'SyNx',
#  'SyrsoN',
#  'TabseN',
#  'TahsiN',
#  'TiziaN',
#  'Tow_b',
#  'TuGuX',
#  'Veniq',
#  'Xenn',
#  'Awzek',
#  'Aaron',
#  'Bodito',
#  'Coolio',
#  'Flashie',
#  'Fleav',
#  'Gabesson',
#  'Kamion',
#  'Kolor',
#  'Kory',
#  'MsN',
#  'Nylon',
#  'Sl3nd',
#  'Torzsi',
#  'ZEN',
#  'Allee',
#  'Bjarni',
#  'CaPPiNg!',
#  'ClvR',
#  'DeNos',
#  'EddezeNNN',
#  'Goa7er',
#  'Kruzer',
#  'Ofvirkur',
#  'Peterr',
#  'SPiKe',
#  'TH0R',
#  'ArTisT',
#  'CINDER',
#  'Extinct',
#  'VertiGo',
#  'FUSiON',
#  'KIMERA',
#  'Cerber',
#  'Deb0',
#  'Dementor',
#  'Gejmzilla',
#  'Gulito',
#  'Gxx-',
#  'Juanflatroo',
#  'SENER1',
#  'Sinnopsyy',
#  'Broky',
#  'EIZA',
#  'Flarich',
#  'Hyskeee',
#  'Independent',
#  'Keen',
#  'Krii',
#  'PrelideN',
#  'R0b3n',
#  'Shield',
#  'YEKINDAR',
#  'Butters',
#  'Bymas',
#  'EspiranTo',
#  'Haflex',
#  'JL',
#  'Kalinka',
#  'Kvik',
#  'LukjjE',
#  'Maty',
#  'Pounh',
#  'Marix',
#  'AidKiT',
#  'CacaNito',
#  'Dan1',
#  'Kyxsan',
#  'Necrogenes1s',
#  'NENO',
#  'StYleEeZ',
#  'Lobanjica',
#  'Maden',
#  'Bernard',
#  'Blackie',
#  'ChrisJ',
#  'Clash',
#  'CRUC1AL',
#  'D0cC',
#  'FASHR',
#  'G1DO',
#  'Luosrevo',
#  'Rezst',
#  'Rilax',
#  'V1N',
#  'AkEz',
#  'ANdz',
#  'Aurora',
#  'Becker',
#  'Cromen',
#  'Enix',
#  'Fletch',
#  'Grus',
#  'H4RR3',
#  'Hallzerk',
#  'Hedje',
#  'HEllberg',
#  'Jimbo',
#  'Jkaem',
#  'Kalle',
#  'KORN',
#  'LaX',
#  'Marcelious',
#  'Mattye',
#  'Mikki',
#  'NiTo',
#  'Philip',
#  'Phnien',
#  'Polly',
#  'Radifaction',
#  'Rain',
#  'RashiiiE',
#  'RoSeY',
#  'Ruyter',
#  'Sense',
#  'Shyyne',
#  'SLY',
#  'Truth',
#  'VENdetta',
#  'VHw',
#  'Zame',
#  'ZEVES',
#  'Ztk',
#  'Zykes',
#  'Azizz',
#  'Baljs',
#  'Blacktear5',
#  'Bnox',
#  'Bogdan',
#  'Byali',
#  'Casey',
#  'Crityourface',
#  'Darchevile',
#  'Darko',
#  'Demho',
#  'DESTROJ',
#  'Dycha',
#  'Enzo',
#  'EXUS',
#  'F1KU',
#  'Fr3nd',
#  'Fullspeed',
#  'Furlan',
#  'GaB',
#  'Goofy',
#  'GruBy',
#  'GRuChA',
#  'Hades_(Polish_player)',
#  'Hyper_(Polish_player)',
#  'IMD',
#  'Innocent',
#  'Iso',
#  'Jedqr',
#  'KEi',
#  'KRaSnaL',
#  'Kuben',
#  'KubiK',
#  'Kylar',
#  'Layner',
#  'Leman',
#  'Loord',
#  'LunAtic',
#  'Luz',
#  'M4tthi',
#  'Maaryy',
#  'Mantuu',
#  'Markoś',
#  'MASKED',
#  'Matty',
#  'MepsoN',
#  'MhL',
#  'MICHU',
#  'MiNIr0x',
#  'MINISE',
#  'Mono',
#  'Morelz',
#  'Mouz_(Polish_player)',
#  'MSr',
#  'Mynio',
#  'N0tice',
#  'Nawrot',
#  'NEO',
#  'OKOLICIOUZ',
#  'OLIMP',
#  'Oskarish',
#  'PashaBiceps',
#  'Phr',
#  'Ponczek',
#  'Prism',
#  'Rallen',
#  'Reatz',
#  'Reiko',
#  'Repo',
#  'Riczi_Maszynka',
#  'Sany',
#  'SAYN',
#  'Sidney',
#  'Siuhy',
#  'Snatchie',
#  'Snax',
#  'SNx',
#  'Sobol',
#  'Splawik',
#  'STOMP',
#  'Szejn',
#  'SZPERO',
#  'TaZ',
#  'TOAO',
#  'ToM223',
#  'Tomiko',
#  'TudsoN',
#  'Vegi',
#  'VinS',
#  'ZaNNN',
#  'Ag1l',
#  'AIm',
#  'Arrozdoce',
#  'BLOODZ',
#  'BuJ',
#  'CarboN',
#  'Coachi',
#  'D10S',
#  'DDias',
#  'Ewjerkz',
#  'FakeS2',
#  'Fox_(Portuguese_player)',
#  'JTR',
#  'JUST',
#  'Juve',
#  'Kst',
#  'MISK',
#  'MUTiRiS',
#  'NABOWOW',
#  'NOPEEj',
#  'Obj',
#  'Pizituh',
#  'Plat',
#  'Pr',
#  'Psh',
#  'RafaxF',
#  'Renatoohaxx',
#  'RIZZ',
#  'Rmn',
#  'Shellzi',
#  'Slaxx',
#  'Snapy',
#  'Stadodo',
#  'Story',
#  'Torres',
#  'Vsk',
#  'Vts',
#  'W0rms',
#  'Whatz',
#  'ZELIN',
#  'Zlynx',
#  'AdamS',
#  'AdeX',
#  'ADRON',
#  'ANa',
#  'Blytz',
#  'BTN',
#  'FNk',
#  'GEOHYPE',
#  'ILLa',
#  'IM',
#  'LauNX',
#  'MhN1',
#  'MoDo',
#  'NJ',
#  'R1d3r',
#  'Ragga',
#  'Regali',
#  'SEMINTE',
#  'Smekk',
#  'Starkiller',
#  'Swiiffter',
#  'SXe',
#  'WHiTE',
#  'XELLOW',
#  'Zewts',
#  'AVN',
#  'C0llins',
#  'Choiv7',
#  'DEE',
#  'DiMKE',
#  'Djokabomba',
#  'Dragon',
#  'Emi',
#  'Fajkus',
#  'Feedme',
#  'HOLMES',
#  'Impulse',
#  'K1Ng0r',
#  'Kassad',
#  'Kind0',
#  'Lacore',
#  'LETN1',
#  'Nexa',
#  'PTKKK',
#  'SkippeR',
#  'SoLo',
#  'VLDN',
#  'Zon1Q',
#  'Adejis',
#  'EMENK',
#  'Frozen',
#  'GuardiaN',
#  'HenkkyG',
#  'Jaro',
#  'Kat',
#  'KETUBOR',
#  'Luko',
#  'Matys',
#  'MAXX',
#  'NIO',
#  'Queztone',
#  'SAvana1',
#  'Shhhack',
#  'STYKO',
#  'System',
#  'The_eLiVe',
#  'ZEDc',
#  'Zero',
#  'Adrig6',
#  'ALEX_(Spanish_player)',
#  'Arki',
#  'BladE',
#  'Blastinho',
#  'Cr0n0s',
#  'Dav1g',
#  'DeathZz',
#  'Drifking',
#  'EasTor',
#  'Enanoks',
#  'FeldmaN',
#  'Geck0',
#  'Hepa',
#  'KALAS',
#  'Kanarito',
#  'Kinta',
#  'MeisoN',
#  'MissLaia',
#  'Mopoz',
#  'MusambaN1',
#  'NaOw',
#  'Nmt',
#  'Peelk',
#  'Sausol',
#  'Smile',
#  'SOKER',
#  'Spanisfury',
#  'SunPayus',
#  'TorPe',
#  'V1NCHENSO7',
#  'Xikii',
#  'YuRk0',
#  'Adamb',
#  'Addi',
#  'Adx',
#  'AlekS',
#  'AybeN',
#  'B0bbzki',
#  'B0denmaster',
#  'BENDJI',
#  'Benny',
#  'Bishop',
#  'Blandfers',
#  'Bobeksde',
#  'Bq',
#  'Brollan',
#  'Bugge',
#  'Bullen',
#  'Bååten',
#  'CEYN',
#  'Chawzyyy',
#  'Chrille',
#  'Darti',
#  'Dennis',
#  'Devilwalk',
#  'Dezon',
#  'DH',
#  'Disco_doplan',
#  'DjL',
#  'DORFEN',
#  'Downie',
#  'Draken_(William_Sundin)',
#  'Dumas',
#  'Elo',
#  'Eraa',
#  'F0rest',
#  'FliCkat',
#  'Flusha',
#  'Fragaria',
#  'FRANSSON',
#  'FREDDyFROG',
#  'Friberg',
#  'GAME',
#  'Goffe',
#  'Golden',
#  'Grux',
#  'Hampus',
#  'HEAP',
#  'Hemzk9',
#  'Hns',
#  'Huggan',
#  'HugoXD',
#  'Hype',
#  'Isak',
#  'Jackinho',
#  'JAEGARN',
#  'JayzaR',
#  'Jayzwalkingz',
#  'Joel',
#  'JW',
#  'Karma',
#  'Kevve_(Swedish_player)',
#  'Kevzy',
#  'Khobra',
#  'Kicker',
#  'Kreaz',
#  'KriLLe',
#  'KRIMZ',
#  'Kurtaliz',
#  'LBNS',
#  'Lekr0',
#  'Limp',
#  'LNZ',
#  'Lunedi',
#  'Maektig',
#  'Malle',
#  'Mann3n',
#  'MEKO',
#  'Melonhead',
#  'Minio',
#  'MODDII',
#  'MokeN',
#  'Mrtn_(Swedish_player)',
#  'Nawwk',
#  'Nessa',
#  'Nilo',
#  'Olofmeister',
#  'PALM1',
#  'Pauf',
#  'Peppzor',
#  'Per0N',
#  'Phzy',
#  'Pita',
#  'PlesseN',
#  'Plopski',
#  'Ponkus',
#  'Puffran',
#  'Pupcake',
#  'Quix',
#  'Relaxa',
#  'Relife',
#  'REZ',
#  'Ro1f',
#  'RobbaN',
#  'Robiin',
#  'Roque',
#  'RuStY',
#  'S1ck',
#  'Sapec',
#  'SHiNE',
#  'Slap',
#  'Speedi',
#  'Spooke',
#  'Susp',
#  'Svedjehed',
#  'T3h_f4rm3r',
#  'Tabz',
#  'Tease',
#  'Tedderzy',
#  'Tvs',
#  'Twist',
#  'WLTR',
#  'WolfY',
#  'Xaisty',
#  'Xajdish',
#  'Xelos',
#  'Xizt',
#  'Yeahnie',
#  'ZAAz',
#  'Zen',
#  'Zende',
#  'ZER',
#  'ZINKEN',
#  'Zitte',
#  'Znajder',
#  'Ztr',
#  'Zyppe',
#  'EleKz',
#  'Freelance',
#  'MALI',
#  'RigoN',
#  'XReal',
#  'Zed',
#  'Bishop_(Turkish_player)',
#  'Calyx',
#  'Hardstyle',
#  'ImoRR',
#  'MAJ3R',
#  'Paz',
#  'REOVA',
#  'Soulfly',
#  'Woxic',
#  'XANTARES',
#  'Xfl0ud',
#  'Adam9130',
#  'ALEX_(British_player)',
#  'Ashhh',
#  'Astroo',
#  'Cryths',
#  'CYPHER',
#  'DeXter',
#  'Dobbo',
#  'Dox',
#  'EMy',
#  'Frazehh',
#  'Girafffe',
#  'Jenko',
#  'Keita',
#  'KiTTy-KaT',
#  'Kray',
#  'Leaf_(British_player)',
#  'LS',
#  'Luzuh',
#  'Maza',
#  'Mezii',
#  'MiGHTYMAX',
#  'Mrhui',
#  'Nukeddog',
#  'Peggyyyyy',
#  'Ping',
#  'Resu',
#  'ReTr00',
#  'SamE',
#  'SHANEY',
#  'Sheekey',
#  'Smooya',
#  'Surreal',
#  'Swaggy',
#  'Tadpole',
#  'Thomas',
#  'VANITY_(British_player)',
#  'Volt',
#  'Wh1sk',
#  'Whindanski',
#  'Whitey',
#  'Wilksyy',
#  'Znx']

# %%
def total_players():
    total = 0
    for major_region, sub_regions in REGIONS.items():
        for region in sub_regions:
            total += len(fetch_ids(region))
    return total

#total_players()

# %%
def fetch_player(player_name, region, major_list, debug=False):
    # pull player profile
    soup = fetch_page(player_name)
    output_dict = dict()
    
    # parse player information
    info_list = soup.find_all("div", {"class": "infobox-cell-2"})
    info_dict = {info_list[i].text[:-1] : info_list[i+1].text for i in range(0, len(info_list),2)}
    if debug:
        print(info_dict)
    # add name to dict
    output_dict["NAME"] = player_name
    output_dict["REGION"] = region
    
    # replace name with romanised name if needed
    if "Romanized Name" in info_dict:
        output_dict["REAL NAME"] = info_dict["Romanized Name"]
    else:
        output_dict["REAL NAME"] = info_dict["Name"]
    
    # get nationality
    if "Nationality" in info_dict:
        output_dict["NATIONALITY"] = info_dict["Nationality"][1:]
    
    # get team
    if "Team"  in info_dict:
        output_dict["TEAM"] = info_dict["Team"]
    
    # Get age
    if "Born" in info_dict:
        try:
            output_dict["AGE"] = datetime.strptime(info_dict["Born"][:-9].replace(",", ""), "%B %d %Y").strftime("%d/%m/%Y")
        except:
            pass
    
    # Get role
    if "Role" in info_dict:
        if "AWPer" in info_dict["Role"]:
            output_dict["WEAPON"] = "AWP"
        else:
            output_dict["WEAPON"] = "AK47"
    elif "Roles" in info_dict:
        if "AWPer" in info_dict["Roles"]:
            output_dict["WEAPON"] = "AWP"
        else:
            output_dict["WEAPON"] = "AK47"
            
    # Get major appearances
    try:
        soup = fetch_page(player_name + "/Results")
        event_elements = soup.find_all("tr", {"class": "valvemajor-highlighted"})
        event_name_list = [event.find("td", {"style": "text-align:left"}).find("a")["href"] for event in event_elements]
        event_name_list = [event for event in event_name_list if event in major_list]
        output_dict["MAJOR APPEARANCES"] = len(event_name_list)
    except:
        output_dict["MAJOR APPEARANCES"] = 0
    
    if "Approx. Total Winnings" in info_dict:
        output_dict["EARNINGS"] = info_dict["Approx. Total Winnings"]
    else:
        output_dict["EARNINGS"] = "0$"
    
    output_dict["LAST UPDATED"] = datetime.now().strftime("%d/%m/%Y")
    return output_dict
    
#fetch_player("MingSir", "Eastern_%26_Southern_Asia", fetch_majors(), debug=True)
fetch_player("AntO_oNNN", "CIS", fetch_majors(), debug=True)
# Out:
# {'Name': 'Anton Van Gorp', 'Nationality': '\xa0Belgium', 'Born': 'July 18, 1995 (age\xa027)', 'Status': 'Active', 'Years Active (Org)': '2017 – 2020', 'Years Active (Coach)': '2017 – Present', 'Years Active (Analyst)': '2018 – Present', 'Roles': 'Assistant CoachAnalyst', 'Team': 'Complexity Gaming', 'Games': 'Global Offensive'}
# {'NAME': 'AntO_oNNN',
#  'REGION': 'CIS',
#  'REAL NAME': 'Anton Van Gorp',
#  'NATIONALITY': 'Belgium',
#  'TEAM': 'Complexity Gaming',
#  'AGE': '18/07/1995',
#  'WEAPON': 'AK47',
#  'MAJOR APPEARANCES': 0,
#  'EARNINGS': '0$',
#  'LAST UPDATED': '14/10/2022'}

# %%
def build_df():
    # Get dataframe to werite to
    if os.path.exists(CSV_FILE):
        playerdata = pd.read_csv(CSV_FILE)
    else:
        playerdata = pd.DataFrame(columns=COLUMNS)
        
    # Get list of all mayors
    major_list = fetch_majors()

    try:
        for major_region, sub_regions in tqdm(REGIONS.items()):
            for sub_region in tqdm(sub_regions, leave=False):
                region_ids = fetch_ids(sub_region)
                for player in tqdm(region_ids, leave=False):
                    if not (playerdata["NAME"].eq(player)).any():
                        row_data = fetch_player(player, major_region, major_list)
                        playerdata = pd.concat([playerdata, pd.DataFrame.from_records([row_data])], ignore_index=True)
    except Exception as e:
        print("Error:", e)
    
    playerdata.to_csv(CSV_FILE, index=False)
    return

build_df()
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/958 [00:00<?, ?it/s]
# Error: [Errno Expecting value] <!DOCTYPE HTML><title>Rate Limited</title><meta charset=utf-8><meta name=viewport content="width=device-width,initial-scale=1"><style type=text/css>body{margin:40px auto;max-width:700px;line-height:1.6;font-size:18px;color:#444;padding:0 10px}h1{line-height:1.2}.reason{display:none}</style><script src=https://www.recaptcha.net/recaptcha/api.js></script><h1>Rate Limited</h1><p>Your IP address has been temporarily blocked from accessing Liquipedia due to excessive or invalid requests. This may happen if you're using a scraper / bot or otherwise accessing pages too quickly. Scrapers and similar tools are not permitted to access Liquipedia. Please see <a href=/api-terms-of-use>the Liquipedia API terms of use</a> for information on how to access to Liquipedia data in a supported manner. Rate limiting may also be triggered by problematic browser extensions, excessive pre-fetching or corporate content scanners. If you still aren't sure why you were rate limited, you can <a href=https://discord.gg/liquipedia>contact us on Discord</a>.<div id=cheetah class=reason><h2>Cheetah Browser Detected</h2><p>You seem to be using "Cheetah Browser" / "CM Browser" / "çè±¹å®å¨æµè§å¨". This browser opens many connections to Liquipedia as part of the preloading feature. Please disable the preloading feature in order to avoid becoming blocked due to this browser.</div><p>To restore access to Liquipedia, please complete the CAPTCHA to unblock your IP:<form method=post action=/unblock><input type=hidden name=r id=r><div class=g-recaptcha data-sitekey=6LfmmiMUAAAAAM6iunApG9ilrc4jTIUcOfv9xYNX></div><br><label><input type=checkbox name=agree value=1> I agree to follow the <a href=/api-terms-of-use>Liquipedia API terms of use</a></label><br><input type=submit value=Unblock></form><p><p>Note that unblocking your IP will not whitelist it; you may still be rate limited again if you do not fix whatever caused you to be blocked. <strong>Repeated triggering of rate limits may result in them becoming permanent.</strong></p><script>document.getElementById('r').value = window.location.href;if (navigator.userAgent.indexOf ("LBBROWSER") != -1)document.getElementById('cheetah').style.display = "block";</script><!-- Triggered by REMOTE_ADDR for REQUEST_URI at TIME_ISO8601 -->: 0

# %%
playerdata = pd.read_csv(CSV_FILE)

# %%
#playerdata
